# %% [markdown]
# <a href="https://colab.research.google.com/github/outlaw-xd/stock_index/blob/main/usa_stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/yv55xz5h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/vusf9ube.json
# 📊 S&P 500 Overview
# Current Price     : 5980.87
# Max Price         : 6144.15
# Min Price         : 3009.05
# 7-Day Trend       : 🔽 Downward
# --------------------------------------------------
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99691', 'data', 'file=/tmp/tmprluoxvoi/yv55xz5h.json', 'init=/tmp/tmprluoxvoi/vusf9ube.json', 'output', 'file=/tmp/tmprluoxvoi/prophet_model6xhvozk8/prophet_model-20250620194643.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:46:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:46:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 🔮 S&P 500 Forecast - 1 Year (365 days)
#              ds         yhat
# 2715 2029-06-18  7394.635908
# 2716 2029-06-19  7390.829710
# 2717 2029-06-20  7390.793288
# 2718 2029-06-21  7387.338826
# 2719 2029-06-22  7388.209691
# 🔮 S&P 500 Forecast - 2 Years (730 days)
#              ds         yhat
# 2350 2028-06-18  6981.614123
# 2351 2028-06-19  6997.308149
# 2352 2028-06-20  6993.859056
# 2353 2028-06-21  6994.284559
# 2354 2028-06-22  6991.389826
# 🔮 S&P 500 Forecast - 5 Years (1825 days)
#              ds         yhat
# 1255 2025-06-19  5810.603819
# 1256 2025-06-20  5810.676687
# 1257 2025-06-21  5792.391629
# 1258 2025-06-22  5791.515480
# 1259 2025-06-23  5808.732262
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/8uv939q3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/vsuhwp0d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99402', 'data', 'file=/tmp/tmprluoxvoi/8uv939q3.json', 'init=/tmp/tmprluoxvoi/vsuhwp0d.json', 'output', 'file=/tmp/tmprluoxvoi/prophet_model6sq5zik1/prophet_model-20250620194646.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:46:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 📊 Dow Jones Overview
# Current Price     : 42171.66
# Max Price         : 45014.04
# Min Price         : 25015.55
# 7-Day Trend       : 🔽 Downward
# --------------------------------------------------
# 19:46:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 🔮 Dow Jones Forecast - 1 Year (365 days)
#              ds          yhat
# 2715 2029-06-18  51321.887899
# 2716 2029-06-19  51290.960977
# 2717 2029-06-20  51293.147183
# 2718 2029-06-21  51263.995557
# 2719 2029-06-22  51265.529067
# 🔮 Dow Jones Forecast - 2 Years (730 days)
#              ds          yhat
# 2350 2028-06-18  48788.787750
# 2351 2028-06-19  48915.688550
# 2352 2028-06-20  48888.407503
# 2353 2028-06-21  48894.858844
# 2354 2028-06-22  48870.544237
# 🔮 Dow Jones Forecast - 5 Years (1825 days)
#              ds          yhat
# 1255 2025-06-19  41752.192784
# 1256 2025-06-20  41746.557434
# 1257 2025-06-21  41595.890571
# 1258 2025-06-22  41588.232969
# 1259 2025-06-23  41728.722978
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/bx6jqria.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/uxxfarjd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19795', 'data', 'file=/tmp/tmprluoxvoi/bx6jqria.json', 'init=/tmp/tmprluoxvoi/uxxfarjd.json', 'output', 'file=/tmp/tmprluoxvoi/prophet_modelb9t6zasw/prophet_model-20250620194648.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:46:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 📊 NASDAQ Overview
# Current Price     : 21719.69
# Max Price         : 22175.60
# Min Price         : 9849.36
# 7-Day Trend       : 🔽 Downward
# --------------------------------------------------
# 19:46:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 🔮 NASDAQ Forecast - 1 Year (365 days)
#              ds          yhat
# 2715 2029-06-18  28166.181198
# 2716 2029-06-19  28157.482202
# 2717 2029-06-20  28160.939004
# 2718 2029-06-21  28155.154683
# 2719 2029-06-22  28161.813213
# 🔮 NASDAQ Forecast - 2 Years (730 days)
#              ds          yhat
# 2350 2028-06-18  26349.899247
# 2351 2028-06-19  26389.057057
# 2352 2028-06-20  26381.510650
# 2353 2028-06-21  26386.562270
# 2354 2028-06-22  26382.778700
# 🔮 NASDAQ Forecast - 5 Years (1825 days)
#              ds          yhat
# 1255 2025-06-19  21050.842899
# 1256 2025-06-20  21054.704975
# 1257 2025-06-21  21022.302501
# 1258 2025-06-22  21024.881003
# 1259 2025-06-23  21069.382501
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/4xdhrp0r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/5uejwso0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89766', 'data', 'file=/tmp/tmprluoxvoi/4xdhrp0r.json', 'init=/tmp/tmprluoxvoi/5uejwso0.json', 'output', 'file=/tmp/tmprluoxvoi/prophet_modelgftmny0r/prophet_model-20250620194650.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:46:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 📊 Russell 2000 Overview
# Current Price     : 2112.96
# Max Price         : 2442.74
# Min Price         : 1378.78
# 7-Day Trend       : 🔽 Downward
# --------------------------------------------------
# 19:46:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 🔮 Russell 2000 Forecast - 1 Year (365 days)
#              ds         yhat
# 2715 2029-06-18  1831.516502
# 2716 2029-06-19  1829.285023
# 2717 2029-06-20  1826.737748
# 2718 2029-06-21  1823.146322
# 2719 2029-06-22  1821.170627
# 🔮 Russell 2000 Forecast - 2 Years (730 days)
#              ds         yhat
# 2350 2028-06-18  1889.973717
# 2351 2028-06-19  1886.949855
# 2352 2028-06-20  1884.703796
# 2353 2028-06-21  1882.219984
# 2354 2028-06-22  1878.770611
# 🔮 Russell 2000 Forecast - 5 Years (1825 days)
#              ds         yhat
# 1255 2025-06-19  2062.201813
# 1256 2025-06-20  2060.077396
# 1257 2025-06-21  2058.761069
# 1258 2025-06-22  2056.418316
# 1259 2025-06-23  2053.702392

# %%
def analyze_and_forecast(file_path, index_name):
    import pandas as pd
    import matplotlib.pyplot as plt
    from prophet import Prophet
    from datetime import datetime

    # 🔹 Load and clean data
    df = pd.read_csv(file_path)
    df.rename(columns={'Date': 'ds', 'Close/Last': 'y'}, inplace=True)
    df['ds'] = pd.to_datetime(df['ds'], errors='coerce')
    df['y'] = df['y'].astype(str).str.replace('$', '', regex=False).str.replace(',', '', regex=False)
    df['y'] = pd.to_numeric(df['y'], errors='coerce')
    df = df.dropna(subset=['ds', 'y']).drop_duplicates(subset='ds').sort_values('ds')

    # 🔧 Shift data to end at today
    latest_ds = df['ds'].max()
    today = pd.Timestamp.today().normalize()
    shift_days = (today - latest_ds).days
    df['ds'] = df['ds'] + pd.Timedelta(days=shift_days)

    # 📊 Summary
    current_price = df['y'].iloc[-1]
    max_price = df['y'].max()
    min_price = df['y'].min()
    trend = "🔼 Upward" if df['y'].iloc[-1] > df['y'].iloc[-7] else "🔽 Downward"

    print(f"\n📊 {index_name} Overview")
    print(f"Current Price     : {current_price:.2f}")
    print(f"Max Price         : {max_price:.2f}")
    print(f"Min Price         : {min_price:.2f}")
    print(f"7-Day Trend       : {trend}")
    print("-" * 50)

    # 🔮 Forecast with Prophet
    model = Prophet(daily_seasonality=True)
    model.fit(df)
    forecast = model.predict(model.make_future_dataframe(periods=1825))

    # 🔁 Forecast periods
    periods = {
        '1 Year (365 days)': 365,
        '2 Years (730 days)': 730,
        '5 Years (1825 days)': 1825
    }

    for label, days in periods.items():
        # ⏳ Filter from today onward
        future_range = forecast[['ds', 'yhat']][forecast['ds'] >= today].head(days).copy()
        future_range['yhat_smooth'] = future_range['yhat'].rolling(window=7, min_periods=1).mean()

        print(f"\n🔮 {index_name} Forecast - {label}")
        display(future_range[['ds', 'yhat']].head())

        # 📈 Plot
        plt.figure(figsize=(12, 5))
        plt.plot(df['ds'], df['y'], label='Historical Data', color='black')
        plt.plot(future_range['ds'], future_range['yhat_smooth'], label=f'{label} Forecast', linewidth=2)
        plt.title(f"{index_name} Forecast - {label}")
        plt.xlabel("Date")
        plt.ylabel("Price")
        plt.xticks(rotation=45)
        plt.grid(True)
        plt.legend()
        plt.tight_layout()
        plt.show()

# %%
base_path = '/content/drive/MyDrive/StockData'

analyze_and_forecast(f'{base_path}/SnP.csv', 'S&P 500')
analyze_and_forecast(f'{base_path}/downjones.csv', 'Dow Jones')
analyze_and_forecast(f'{base_path}/nasdaq.csv', 'NASDAQ')
analyze_and_forecast(f'{base_path}/rut.csv', 'Russell 2000')
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/jeuspgup.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/sp0lwgxn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86412', 'data', 'file=/tmp/tmprluoxvoi/jeuspgup.json', 'init=/tmp/tmprluoxvoi/sp0lwgxn.json', 'output', 'file=/tmp/tmprluoxvoi/prophet_modeliflca2g7/prophet_model-20250620195202.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:52:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 📊 S&P 500 Overview
# Current Price     : 5980.87
# Max Price         : 6144.15
# Min Price         : 3009.05
# 7-Day Trend       : 🔽 Downward
# --------------------------------------------------
# 19:52:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 🔮 S&P 500 Forecast - 1 Year (365 days)
#              ds         yhat
# 1254 2025-06-20  5815.580761
# 1255 2025-06-21  5811.479731
# 1256 2025-06-22  5811.544224
# 1257 2025-06-23  5793.980135
# 1258 2025-06-24  5793.080189
# 🔮 S&P 500 Forecast - 2 Years (730 days)
#              ds         yhat
# 1254 2025-06-20  5815.580761
# 1255 2025-06-21  5811.479731
# 1256 2025-06-22  5811.544224
# 1257 2025-06-23  5793.980135
# 1258 2025-06-24  5793.080189
# 🔮 S&P 500 Forecast - 5 Years (1825 days)
#              ds         yhat
# 1254 2025-06-20  5815.580761
# 1255 2025-06-21  5811.479731
# 1256 2025-06-22  5811.544224
# 1257 2025-06-23  5793.980135
# 1258 2025-06-24  5793.080189
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/brtgscas.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/re254021.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64296', 'data', 'file=/tmp/tmprluoxvoi/brtgscas.json', 'init=/tmp/tmprluoxvoi/re254021.json', 'output', 'file=/tmp/tmprluoxvoi/prophet_modelt4dcek8u/prophet_model-20250620195204.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:52:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 📊 Dow Jones Overview
# Current Price     : 42171.66
# Max Price         : 45014.04
# Min Price         : 25015.55
# 7-Day Trend       : 🔽 Downward
# --------------------------------------------------
# 19:52:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 🔮 Dow Jones Forecast - 1 Year (365 days)
#              ds          yhat
# 1254 2025-06-20  41781.820243
# 1255 2025-06-21  41746.127716
# 1256 2025-06-22  41740.219659
# 1257 2025-06-23  41589.347313
# 1258 2025-06-24  41581.378025
# 🔮 Dow Jones Forecast - 2 Years (730 days)
#              ds          yhat
# 1254 2025-06-20  41781.820243
# 1255 2025-06-21  41746.127716
# 1256 2025-06-22  41740.219659
# 1257 2025-06-23  41589.347313
# 1258 2025-06-24  41581.378025
# 🔮 Dow Jones Forecast - 5 Years (1825 days)
#              ds          yhat
# 1254 2025-06-20  41781.820243
# 1255 2025-06-21  41746.127716
# 1256 2025-06-22  41740.219659
# 1257 2025-06-23  41589.347313
# 1258 2025-06-24  41581.378025
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/rvxrjyzl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/pvefcgmp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21035', 'data', 'file=/tmp/tmprluoxvoi/rvxrjyzl.json', 'init=/tmp/tmprluoxvoi/pvefcgmp.json', 'output', 'file=/tmp/tmprluoxvoi/prophet_modelu28b__d0/prophet_model-20250620195206.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:52:06 - cmdstanpy - INFO - Chain [1] start processing
# 📊 NASDAQ Overview
# Current Price     : 21719.69
# Max Price         : 22175.60
# Min Price         : 9849.36
# 7-Day Trend       : 🔽 Downward
# --------------------------------------------------
# INFO:cmdstanpy:Chain [1] start processing
# 19:52:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 🔮 NASDAQ Forecast - 1 Year (365 days)
#              ds          yhat
# 1254 2025-06-20  21063.333002
# 1255 2025-06-21  21055.299745
# 1256 2025-06-22  21059.035186
# 1257 2025-06-23  21025.616666
# 1258 2025-06-24  21028.033223
# 🔮 NASDAQ Forecast - 2 Years (730 days)
#              ds          yhat
# 1254 2025-06-20  21063.333002
# 1255 2025-06-21  21055.299745
# 1256 2025-06-22  21059.035186
# 1257 2025-06-23  21025.616666
# 1258 2025-06-24  21028.033223
# 🔮 NASDAQ Forecast - 5 Years (1825 days)
#              ds          yhat
# 1254 2025-06-20  21063.333002
# 1255 2025-06-21  21055.299745
# 1256 2025-06-22  21059.035186
# 1257 2025-06-23  21025.616666
# 1258 2025-06-24  21028.033223
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/6zlb0dur.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmprluoxvoi/l9u7e2rn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40166', 'data', 'file=/tmp/tmprluoxvoi/6zlb0dur.json', 'init=/tmp/tmprluoxvoi/l9u7e2rn.json', 'output', 'file=/tmp/tmprluoxvoi/prophet_modelg4lruejg/prophet_model-20250620195209.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:52:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 📊 Russell 2000 Overview
# Current Price     : 2112.96
# Max Price         : 2442.74
# Min Price         : 1378.78
# 7-Day Trend       : 🔽 Downward
# --------------------------------------------------
# 19:52:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 🔮 Russell 2000 Forecast - 1 Year (365 days)
#              ds         yhat
# 1254 2025-06-20  2061.889478
# 1255 2025-06-21  2058.064537
# 1256 2025-06-22  2055.788633
# 1257 2025-06-23  2051.374683
# 1258 2025-06-24  2048.863950
# 🔮 Russell 2000 Forecast - 2 Years (730 days)
#              ds         yhat
# 1254 2025-06-20  2061.889478
# 1255 2025-06-21  2058.064537
# 1256 2025-06-22  2055.788633
# 1257 2025-06-23  2051.374683
# 1258 2025-06-24  2048.863950
# 🔮 Russell 2000 Forecast - 5 Years (1825 days)
#              ds         yhat
# 1254 2025-06-20  2061.889478
# 1255 2025-06-21  2058.064537
# 1256 2025-06-22  2055.788633
# 1257 2025-06-23  2051.374683
# 1258 2025-06-24  2048.863950
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['yhat'].plot(kind='hist', bins=20, title='yhat')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['ds']
#   ys = series['yhat']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_1.sort_values('ds', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('ds')
# _ = plt.ylabel('yhat')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['ds']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'ds'}, axis=1)
#               .sort_values('ds', ascending=True))
#   xs = counted['ds']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('ds', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('ds')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['yhat'].plot(kind='line', figsize=(8, 4), title='yhat')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-27-2115973873.py in <cell line: 0>()
#       2 import pandas as pd
#       3
# ----> 4 summary_df = pd.DataFrame(forecast_summary)
#       5 summary_df = summary_df[['Index', '1 Year Forecast', '2 Year Forecast', '5 Year Forecast']]
#       6 summary_df.style.set_caption("📈 Forecast Summary (Prophet Model)")
#
# NameError: name 'forecast_summary' is not defined
